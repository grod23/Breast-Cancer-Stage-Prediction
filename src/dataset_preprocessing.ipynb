# %% [markdown]
# Input Directory Format Example:
#
# Breast_Cancer_Dataset
#
# ------Duke-Breast-Cancer-MRI
#
# -------------Breast_MRI_001
#
# ---------------------01-01-1990-NA-MRI BREAST BILATERAL WWO-97538
#
# ------------------------------------3.000000-ax dyn pre-93877
#
# ------------------------------------5.000000-ax dyn 1st pass-59529
#
# ------------------------------------8.000000-ax dyn 2nd pass-92755
#
# ------------------------------------11.000000-ax dyn 3rd pass-41458
#
# ------------------------------------14.000000-ax dyn 4th pass-47500
#
# -------------------------------------------------1-001.dcm
#
# -------------------------------------------------1-002.dcm
#
# Image sequences should be of similar length.
# Need to train/test split by patient AND seperate by sequence(Image sequence order matters). Each patient will have 5-7 seqeunces in the form of a 3D Tensor. Each patient will have a TNM label. Each patient will have tabular features. Label and features DO NOT differ by sequence. They differ by patient.

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torchvision import transforms
import os
import re

# %%
class Breast_MRI(Dataset):
  def __init__(self, root_dir, labels_csv, features_csv):
    self.root_dir = root_dir
    self.target_size = (224, 224)
    self.transform = transforms.Compose([transforms.ToPILImage(),
                                         transforms.Resize(self.target_size),
                                         transforms.ToTensor()])
    self.corrupted_files = []
    # Load sequences
    self.sequences = self.load_images()
    print(f"Dataset initialized with {len(self.sequences)} sequences")
      
    self.labels = labels_csv
    self.features = features_csv
    
  def __len__(self):
    return len(self.sequences)

  def __getitem__(self, index):
    # """
    #     Returns:
    #         images: [num_slices, H, W] tensor
    #         features: [10] tensor
    #         label: [TNM] int
    # """
      
    sequence_images = []
    sequence_path = self.sequences[index]
    label = 0
    # label = self.labels[index]
    for image_path in sequence_path:
        image = pydicom.dcmread(image_path).pixel_array
        print(f'Image Shape Before Preprocessing: {image.shape}')
        image = self.crop_image(image, image_path)
        image = self.transform(image)
        sequence.append(image)
        print(f'Image Shape After Preprocessing: {image.shape}')
    sequence = torch.stack(sequence_images)  # [num_slices, C, H, W]      
    return sequence, label

  # Load all image paths into its corresponding sequence. Keeps track of patient id and sequence name. Loads sequence into self.sequences
  # Will load and preprocess as sequences of images(3D Tensor)
  def load_images(self):
    # Root Directory: "D:\Breast_Cancer_Dataset\Duke-Breast-Cancer-MRI"

      # """
      #   Load directory structure and organize as SEQUENCES
        
      #   Returns:
      #       List of dicts: [
      #           {'patient_id': 'xx', 'sequence_name': 'yy', 'image_paths': [...]},
      #           ...
      #       ]
      #   """
      
    patients = []
    sequences = []
      
    # 5-7 Seqeunces per patient
    # Need to seperate by sequence AND patient
    for directory in os.listdir(self.root_dir):
        patient_path = os.path.join(self.root_dir, directory)
        patients.append(patient_path)
        
    print(len(patients))
    # Inside each patient folder is a date folder. In that folder is 5-7 sequence folders.
    sequence_folders = []
    for patient in patients:
        # Date Level Folders
        for date_folder in os.listdir(patient): 
            
            if len(os.listdir(patient)) > 1:
                raise Exception('Found More Than 1 Data Folder')
            if len(os.listdir(patient)) == 0:
                raise Exception('NO Date Folder Found')
                  
            date_path = os.path.join(patient, date_folder)
            # Corrupted Folders
            try:
                os.listdir(date_path)
            except (PermissionError, OSError) as e:
                print(f"⚠️ Skipping {patient} due to error: {e}")
                self.corrupted_files.append(date_path)
                continue
            
            # Sequence Level Folders 
            for sequence_folder in os.listdir(date_path):
                sequence_path = os.path.join(date_path, sequence_folder)
                sequence_folders.append(sequence_path)

    # Each sequence folder contains about 50-150 DICOM images.
    for sequence_folder in sequence_folders:
        match = re.search(r'(Breast_MRI_\d+)', sequence_folder)
        patient_id = match.group(1)
        # Image paths for this sequence
        image_paths = []
        sequence_name = os.path.basename(sequence_folder)
        # Step into folder to access DICOM images
         # Corrupted Files
        try:
            os.listdir(sequence_folder)
        except (PermissionError, OSError) as e:
            print(f"⚠️ Skipping {sequence_folder} due to error: {e}")
            self.corrupted_files.append(sequence_folder)
            continue
        for file in os.listdir(sequence_folder):
            image_path = os.path.join(sequence_folder, file)
            image_paths.append(image_path)

        # Add this sequence to our list
        sequences.append({
            'patient_id': patient_id,
            'sequence_name': sequence_name,
            'image_paths': image_paths,
            'num_images': len(image_paths)
        })
        break
        

    print(f'Sequences Length: {len(sequences)}')
    return sequences

    def crop_image(self, image, path):
        # Reduce noise and smooth image.
        new_image = cv2.GaussianBlur(image,(5, 5), 0)

        # Converts image to binary (black and white) pixels above 45 are white(255). Pixels below 45 become black(0).
        # Isolates bright regions in MRI(brain tissue).
        new_image = cv2.threshold(new_image, 28, 255, cv2.THRESH_BINARY)[1]

        # Morphological Operations to smooth and clean binary mask:
        # Helps see contours easily, removes small white noise.
        new_image = cv2.erode(new_image, None, iterations=2)
        # Expands white areas back to original size.
        new_image = cv2.dilate(new_image, None, iterations=2)

        # Send as copy so data is not lost, retrieves only outermost contours(RETR_EXTERNAL).
        contours = cv2.findContours(new_image.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        contours = imutils.grab_contours(contours)

        # Safety Check
        if not contours:
            print("[WARNING] No contours found!")
            print(path)
            return image

        # Get the largest contour by measuring the area. The largest contour will be the outer tissue.
        contours = max(contours, key=cv2.contourArea)
        # Bounding boxes of contour/tissue. Need left, right, top, and bottom.
        ext_left = tuple(contours[contours[:, : , 0].argmin()])[0]
        ext_right = tuple(contours[contours[:, :, 0].argmax()])[0]
        ext_top = tuple(contours[contours[:, :, 1].argmin()])[0]
        ext_bottom = tuple(contours[contours[:, :, 1].argmax()])[0]
    
        # Slice the image through rectangular bounding box.
        cropped_image = image[ext_top[1]: ext_bottom[1], ext_left[0]: ext_right[0]]
        return cropped_image

# %%
root_directory = r"D:\Breast_Cancer_Dataset\Duke-Breast-Cancer-MRI"
mri = Breast_MRI(root_directory, labels_csv=None, features_csv=None)
print(mri.corrupted_files)
# Out:
# 922
# ⚠️ Skipping D:\Breast_Cancer_Dataset\Duke-Breast-Cancer-MRI\Breast_MRI_030 due to error: [WinError 23] Data error (cyclic redundancy check): 'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_030\\01-01-1990-NA-MRI BREAST BILATERAL WWO-47611'
# ⚠️ Skipping D:\Breast_Cancer_Dataset\Duke-Breast-Cancer-MRI\Breast_MRI_042 due to error: [WinError 23] Data error (cyclic redundancy check): 'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_042\\01-01-1990-NA-BREASTlesion evaluation-16139'
# Sequences Length: 1
# Dataset initialized with 1 sequences
# ['D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_030\\01-01-1990-NA-MRI BREAST BILATERAL WWO-47611', 'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_042\\01-01-1990-NA-BREASTlesion evaluation-16139']

# %%
print(len(mri.corrupted_files))
print(len(mri.sequences))
mri.sequences
# Out:
# 2
# 1
# [{'patient_id': <re.Match object; span=(48, 62), match='Breast_MRI_001'>,
#   'sequence_name': '11.000000-ax dyn 3rd pass-41458',
#   'image_paths': ['D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-001.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-002.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-003.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-004.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-005.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-006.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-007.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-008.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-009.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-010.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-011.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-012.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-013.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-014.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-015.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-016.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-017.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-018.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-019.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-020.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-021.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-022.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-023.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-024.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-025.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-026.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-027.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-028.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-029.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-030.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-031.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-032.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-033.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-034.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-035.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-036.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-037.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-038.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-039.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-040.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-041.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-042.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-043.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-044.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-045.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-046.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-047.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-048.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-049.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-050.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-051.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-052.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-053.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-054.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-055.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-056.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-057.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-058.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-059.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-060.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-061.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-062.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-063.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-064.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-065.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-066.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-067.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-068.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-069.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-070.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-071.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-072.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-073.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-074.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-075.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-076.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-077.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-078.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-079.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-080.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-081.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-082.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-083.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-084.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-085.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-086.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-087.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-088.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-089.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-090.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-091.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-092.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-093.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-094.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-095.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-096.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-097.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-098.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-099.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-100.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-101.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-102.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-103.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-104.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-105.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-106.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-107.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-108.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-109.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-110.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-111.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-112.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-113.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-114.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-115.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-116.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-117.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-118.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-119.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-120.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-121.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-122.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-123.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-124.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-125.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-126.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-127.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-128.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-129.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-130.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-131.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-132.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-133.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-134.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-135.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-136.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-137.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-138.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-139.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-140.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-141.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-142.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-143.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-144.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-145.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-146.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-147.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-148.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-149.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-150.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-151.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-152.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-153.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-154.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-155.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-156.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-157.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-158.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-159.dcm',
#    'D:\\Breast_Cancer_Dataset\\Duke-Breast-Cancer-MRI\\Breast_MRI_001\\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\\11.000000-ax dyn 3rd pass-41458\\1-160.dcm'],
#   'num_images': 160}]

# %%
# "D:\Breast_Cancer_Dataset\Duke-Breast-Cancer-MRI\Breast_MRI_001\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\3.000000-ax dyn pre-93877"
sequence = mri.__getitem__(0)
plt.plot(sequence[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # "D:\Breast_Cancer_Dataset\Duke-Breast-Cancer-MRI\Breast_MRI_001\01-01-1990-NA-MRI BREAST BILATERAL WWO-97538\3.000000-ax dyn pre-93877"
# ----> 2 sequence = mri.__getitem__(0)
#       3 plt.plot(sequence[0])
#       4 plt.show()
#
# Cell In[17], line 32, in Breast_MRI.__getitem__(self, index)
#      30 # label = self.labels[index]
#      31 for image_path in sequence_path:
# ---> 32     image = pydicom.dcmread(image_path).pixel_array
#      33     print(f'Image Shape Before Preprocessing: {image.shape}')
#      34     image = self.crop_image(image, image_path)
#
# NameError: name 'pydicom' is not defined
